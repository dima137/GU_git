# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
print(np.__version__)
#from sklearn.metrics import ConfusionMatrixDisplay
#import seaborn
# Out:
# 1.26.4

# %%
ML_folder = '../../data_in/ML_catalogs/'
fn_ML = ML_folder + '4FGL-DR4_v34_cov_shift_vs_prior_shift_prediction.csv'
list_fn = '../../data_in/GU_lists/list_bright_GUs.csv'
fn_out = '../../data_in/GU_lists/list_bright_GUs_ML_classes.csv'

# %%
ML_df = pd.read_csv(fn_ML, index_col=0)
GU_df = pd.read_csv(list_fn, index_col=0)

# %%
names = [name for name in GU_df.index if name in ML_df.index]
names_na = [name for name in GU_df.index if name not in names]

# %%
add_cols = ['RF_class', 'PDF_class', 'Gauss_PDF']
for col in add_cols:
    GU_df.loc[names, col] = ML_df.loc[names, col]
    if col.find('class') > -1:
        GU_df.loc[names_na, col] = 'na'
    else:
        GU_df.loc[names_na, col] = 0.

# %%
GU_df
# Out:
#                     RAJ2000  DEJ2000       LON       LAT RF_class PDF_class  \
# NAME
# 4FGL J0034.6+6438    8.6619  64.6393  121.1340  1.826170     msp+     Gauss
# 4FGL J0057.9+6326   14.4955  63.4385  123.6630  0.576046     bll+      bll+
# 4FGL J0204.7+6656   31.1953  66.9372  130.0390  5.082900     msp+     Gauss
# 4FGL J0235.3+5650   38.8479  56.8478  136.8190 -3.194750     msp+     Gauss
# 4FGL J0616.5+2235   94.1441  22.5943  188.9620  2.905250     psr+      psr+
# ...                     ...      ...       ...       ...      ...       ...
# 4FGL J2114.3+5023  318.5900  50.3993   91.7634  1.148750     psr+     Gauss
# 4FGL J2116.2+3701  319.0590  37.0257   82.3045 -8.341010     msp+     Gauss
# 4FGL J2117.9+3729  319.4920  37.4842   82.8801 -8.273970     msp+     Gauss
# 4FGL J2218.8+4736  334.7240  47.6008   98.0812 -7.775450     msp+      msp+
# 4FGL J2220.8+6319  335.2240  63.3185  106.9500  5.218630     psr+     Gauss
#
#                       Gauss_PDF
# NAME
# 4FGL J0034.6+6438  6.621793e-01
# 4FGL J0057.9+6326  6.562026e-17
# 4FGL J0204.7+6656  8.799811e-01
# 4FGL J0235.3+5650  9.113401e-01
# 4FGL J0616.5+2235  6.742408e-06
# ...                         ...
# 4FGL J2114.3+5023  8.794363e-01
# 4FGL J2116.2+3701  3.773548e-01
# 4FGL J2117.9+3729  5.023317e-01
# 4FGL J2218.8+4736  4.499144e-02
# 4FGL J2220.8+6319  9.481439e-01
#
# [160 rows x 7 columns]

# %%
save_results = True
if save_results:
    print('Save the result to file:')
    print(fn_out)
    GU_df.to_csv(fn_out)
# Out:
# Save the result to file:
# ../../data_in/GU_lists/list_bright_GUs_ML_classes.csv

# %%
GU_df.loc[names_na]
# Out:
#                    RAJ2000  DEJ2000        LON       LAT RF_class PDF_class  \
# NAME
# 4FGL J1526.3-4501  231.598 -45.0303  329.58700  9.672480       na        na
# 4FGL J1801.6-2326  270.424 -23.4345    6.56945 -0.315222       na        na
# 4FGL J1801.8-2358  270.454 -23.9827    6.10680 -0.610649       na        na
# 4FGL J1817.2-3035  274.308 -30.5842    1.94753 -6.780870       na        na
#
#                    Gauss_PDF
# NAME
# 4FGL J1526.3-4501        0.0
# 4FGL J1801.6-2326        0.0
# 4FGL J1801.8-2358        0.0
# 4FGL J1817.2-3035        0.0

# %%
print('Number of bright GU sources: %i' % len(GU_df))
classes = ['bll+', 'fsrq+', 'psr+', 'msp+', 'Gauss']
print('PDF predictions')
for cl in classes:
    print('\t%s candidates: %i' % (cl, sum(GU_df['PDF_class'] == cl)))
print('Fraction of Gaussian candidates: %.3f' % (sum(GU_df['PDF_class'] == 'Gauss')/len(GU_df)))
classes = ['bll+', 'fsrq+', 'psr+', 'msp+']
print('\nRF predictions')
for cl in classes:
    print('\t%s candidates: %i' % (cl, sum(GU_df['RF_class'] == cl)))
# Out:
# Number of bright GU sources: 160
# PDF predictions
# 	bll+ candidates: 5
# 	fsrq+ candidates: 10
# 	psr+ candidates: 11
# 	msp+ candidates: 30
# 	Gauss candidates: 100
# Fraction of Gaussian candidates: 0.625
#
# RF predictions
# 	bll+ candidates: 8
# 	fsrq+ candidates: 2
# 	psr+ candidates: 80
# 	msp+ candidates: 66
